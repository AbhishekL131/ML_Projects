# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
# Out:
# /var/folders/lg/ptvtf8315t182q0k_rny_7c80000gn/T/ipykernel_7789/3228400486.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.value_counts('Seller_Type')
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (301, 9)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
label_encode = LabelEncoder()

# %%
label_fuel = label_encode.fit_transform(df.Fuel_Type)
label_transmission = label_encode.fit_transform(df.Transmission)
label_seller = label_encode.fit_transform(df.Seller_Type)
label_car = label_encode.fit_transform(df.Car_Name)

# %%
df['Car_Name'] = label_car
df['Transmission'] = label_transmission
df['Fuel_Type'] = label_fuel
df['Seller_Type'] = label_seller

# %%
df
# Out:
#      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0          90  2014           3.35           5.59       27000          2
# 1          93  2013           4.75           9.54       43000          1
# 2          68  2017           7.25           9.85        6900          2
# 3          96  2011           2.85           4.15        5200          2
# 4          92  2014           4.60           6.87       42450          1
# ..        ...   ...            ...            ...         ...        ...
# 296        69  2016           9.50          11.60       33988          1
# 297        66  2015           4.00           5.90       60000          2
# 298        69  2009           3.35          11.00       87934          2
# 299        69  2017          11.50          12.50        9000          1
# 300        66  2016           5.30           5.90        5464          2
#
#      Seller_Type  Transmission  Owner
# 0              0             1      0
# ...

# %%
X = df.drop(columns='Selling_Price',axis=1)
Y = df['Selling_Price']

# %%
X
# Out:
#      Car_Name  Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0          90  2014           5.59       27000          2            0
# 1          93  2013           9.54       43000          1            0
# 2          68  2017           9.85        6900          2            0
# 3          96  2011           4.15        5200          2            0
# 4          92  2014           6.87       42450          1            0
# ..        ...   ...            ...         ...        ...          ...
# 296        69  2016          11.60       33988          1            0
# 297        66  2015           5.90       60000          2            0
# 298        69  2009          11.00       87934          2            0
# 299        69  2017          12.50        9000          1            0
# 300        66  2016           5.90        5464          2            0
#
#      Transmission  Owner
# 0               1      0
# 1               1      0
# 2               1      0
# ...

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
standardized_data
# Out:
# array([[ 1.07432341,  0.128897  , -0.23621461, ..., -0.73728539,
#          0.39148015, -0.17450057],
#        [ 1.19182753, -0.21751369,  0.22150462, ..., -0.73728539,
#          0.39148015, -0.17450057],
#        [ 0.21262651,  1.16812909,  0.25742689, ..., -0.73728539,
#          0.39148015, -0.17450057],
#        ...,
#        [ 0.25179455, -1.60315648,  0.39068691, ..., -0.73728539,
#          0.39148015, -0.17450057],
#        [ 0.25179455,  1.16812909,  0.56450434, ..., -0.73728539,
#          0.39148015, -0.17450057],
#        [ 0.13429043,  0.8217184 , -0.20029235, ..., -0.73728539,
#          0.39148015, -0.17450057]])

# %%
X = standardized_data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
X_train.shape , X_test.shape
# Out:
# ((240, 8), (61, 8))

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predicted_data = model.predict(X_test)

# %%
predicted_data
# Out:
# array([10.39621003,  0.69106454,  4.26163824,  4.88444225,  9.84774111,
#         4.24329146,  7.10929401,  7.36044388,  0.19259204,  5.16797228,
#         6.21672617,  6.17485261,  2.09376025,  7.75102877,  1.91473014,
#         1.75041436,  2.03116312,  1.82780172,  9.36113437,  4.26935222,
#         1.48349778,  9.15929197,  1.4661394 ,  9.64107768,  0.78973369,
#         8.09455442,  1.57388176, -3.17889087,  4.22556668,  2.07479725,
#         3.43011653,  3.72575131,  5.57066784,  7.7695858 , -1.89193948,
#         6.79370651,  8.22214312,  5.78427193,  6.16617266,  6.25805647,
#        15.96435725,  2.07726756,  1.05727657, -0.46182643,  6.82306113,
#         6.76340404,  0.98519089,  6.81675873, 14.30690894,  3.02957561,
#         8.05997609, -0.85674187,  9.00026416,  1.11857635,  2.15466675,
#        -0.81446059,  0.7126248 , 10.0351518 , -0.43184819, -2.42723371,
#        10.0767194 ])

# %%
score = metrics.r2_score(Y_test,predicted_data)
score
# Out:
# 0.8403469109875834

# %%
input = (90,2014,5.59,27000,2,0,1,0)

input = np.array(input)

input = input.reshape(1,-1)

input = scaler.transform(input)

predict = model.predict(input)

print(predict)
# Out:
# [3.81124984]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle 
pickle.dump(model,open('model.pkl','wb'))
